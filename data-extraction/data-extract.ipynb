# %%
import requests
from bs4 import BeautifulSoup

def get_full_article(url):
    """Scrapes the full article content from the given URL."""
    try:
        headers = {'User-Agent': 'Mozilla/5.0'}  # Prevent blocking
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            print('start scrapping', url)
            soup = BeautifulSoup(response.text, "html.parser")
            paragraphs = soup.find_all("p")  # Most articles are wrapped in <p> tags
            full_text = " ".join([p.get_text() for p in paragraphs])
            return full_text
        else:
            return "Failed to retrieve article."
    except Exception as e:
        return f"Error: {str(e)}"

# %%
import requests
import pandas as pd
from datetime import datetime, timedelta
from bs4 import BeautifulSoup




# Function to fetch financial news from NewsAPI for a specific day
def fetch_financial_news(api_key, query, date, language="en", page_size=100, page=1):
    url = f"https://newsapi.org/v2/everything"
    params = {
        "q": query,
        "from": date,
        "to": date,
        "language": language,
        "sortBy": "relevancy",
        "pageSize": page_size,
        "page": page,
        "apiKey": api_key
    }
    
    response = requests.get(url, params=params)
    if response.status_code == 200:
        return response.json().get("articles", []), response.json().get("totalResults", 0)
    else:
        print(f"Error: {response.status_code}, {response.json()}")
        return [], 0

# Function to extract news for a specific date range and save it to a single DataFrame
def extract_news_for_month(api_key, query, start_date, end_date):
    current_date = start_date
    all_data = []  # List to hold all articles
    
    while current_date <= end_date:
        print(f"Fetching news for date: {current_date.strftime('%Y-%m-%d')}")
        page = 1
        while True:
            articles, total_results = fetch_financial_news(api_key, query, current_date.strftime("%Y-%m-%d"), page=page)
            if not articles:
                break
            
            for article in articles:
                all_data.append({
                    "Date": article.get("publishedAt", "").split("T")[0],
                    "Title": article.get("title", ""),
                    "Content": get_full_article(article.get("url", "")),
                    "Source": article.get("source", {}).get("name", ""),
                    "URL": article.get("url", "")
                })
            
            print(f"Page {page}: Retrieved {len(articles)} articles (Total: {total_results})")
            
            # Stop fetching if less than 100 articles are retrieved
            if len(articles) < 100:
                break
            page += 1
        
        # Move to the next day
        current_date += timedelta(days=1)
    
    # Convert to DataFrame
    df = pd.DataFrame(all_data)
    return df

# Main execution
if __name__ == "__main__":
    # Replace with your NewsAPI key
    NEWS_API_KEY = "4471fbe1e4c047d7b39d925814199c22"
    
    # Define parameters
    company_name = "Tesla"
    query = f"{company_name} earnings"
    start_date = datetime(2025, 1, 1)  # Start date (YYYY, MM, DD)
    end_date = datetime(2025, 1, 31)  # End date (YYYY, MM, DD)
    output_file = f"{company_name.lower()}_financial_news_january.xlsx"
    
    # Extract news for the month
    news_df = extract_news_for_month(NEWS_API_KEY, query, start_date, end_date)
    
    # Save the DataFrame to Excel
    news_df.to_excel(output_file, index=False, engine="openpyxl")
    print(f"All news data saved to {output_file}")
# Out:
# Fetching news for date: 2025-01-01
# Page 1: Retrieved 10 articles (Total: 10)
# Fetching news for date: 2025-01-02
# Page 1: Retrieved 39 articles (Total: 41)
# Fetching news for date: 2025-01-03
# Page 1: Retrieved 46 articles (Total: 48)
# Fetching news for date: 2025-01-04
# Page 1: Retrieved 11 articles (Total: 11)
# Fetching news for date: 2025-01-05
# Page 1: Retrieved 10 articles (Total: 10)
# Fetching news for date: 2025-01-06
# Page 1: Retrieved 21 articles (Total: 21)
# Fetching news for date: 2025-01-07
# Page 1: Retrieved 18 articles (Total: 19)
# Fetching news for date: 2025-01-08
# Page 1: Retrieved 10 articles (Total: 11)
# Fetching news for date: 2025-01-09
# Page 1: Retrieved 11 articles (Total: 11)
# Fetching news for date: 2025-01-10
# Page 1: Retrieved 25 articles (Total: 26)
# Fetching news for date: 2025-01-11
# Page 1: Retrieved 8 articles (Total: 8)
# Fetching news for date: 2025-01-12
# Page 1: Retrieved 8 articles (Total: 8)
# Fetching news for date: 2025-01-13
# Page 1: Retrieved 20 articles (Total: 20)
# Fetching news for date: 2025-01-14
# Page 1: Retrieved 9 articles (Total: 9)
# Fetching news for date: 2025-01-15
# Page 1: Retrieved 18 articles (Total: 18)
# Fetching news for date: 2025-01-16
# Page 1: Retrieved 7 articles (Total: 7)
# Fetching news for date: 2025-01-17
# Page 1: Retrieved 19 articles (Total: 21)
# Fetching news for date: 2025-01-18
# Page 1: Retrieved 3 articles (Total: 3)
# Fetching news for date: 2025-01-19
# Page 1: Retrieved 8 articles (Total: 8)
# Fetching news for date: 2025-01-20
# Page 1: Retrieved 2 articles (Total: 2)
# Fetching news for date: 2025-01-21
# Page 1: Retrieved 34 articles (Total: 34)
# Fetching news for date: 2025-01-22
# Page 1: Retrieved 20 articles (Total: 20)
# Fetching news for date: 2025-01-23
# Page 1: Retrieved 19 articles (Total: 19)
# Fetching news for date: 2025-01-24
# Page 1: Retrieved 18 articles (Total: 18)
# Fetching news for date: 2025-01-25
# Page 1: Retrieved 12 articles (Total: 12)
# Fetching news for date: 2025-01-26
# Page 1: Retrieved 16 articles (Total: 16)
# Fetching news for date: 2025-01-27
# Page 1: Retrieved 49 articles (Total: 49)
# Fetching news for date: 2025-01-28
# Page 1: Retrieved 48 articles (Total: 50)
# Fetching news for date: 2025-01-29
# Page 1: Retrieved 99 articles (Total: 104)
# Fetching news for date: 2025-01-30
# Fetching news for date: 2025-01-31
# All news data saved to tesla_financial_news_january.xlsx

# %%
news_df#['Content'].value_counts()
# Out:
#            Date                                              Title  \
# 0    2025-01-01  5 Nasdaq Stocks Hitting New 52-Week Highs At Y...
# 1    2025-01-01  The Rich Stop Paying Social Security Tax Aroun...
# 2    2025-01-01  Musk says 'whole Tesla senior team' probing Cy...
# 3    2025-01-01  Bard Financial Services Inc. Reduces Stock Pos...
# 4    2025-01-01  ASML STOCK UPDATE: ASML Holding Investors are ...
# ..          ...                                                ...
# 613  2025-01-29  Tesla’s Fourth-Quarter Earnings Report Sharp D...
# 614  2025-01-29  S&P 500 futures slide ahead of Fed rate decisi...
# 615  2025-01-29  Elon Musk: Tesla will launch unsupervised full...
# 616  2025-01-29  Tesla guides return to growth thanks to cheape...
# 617  2025-01-29  Share Market Highlights 29 January 2025: IT, a...
#
#                                                Content          Source  \
# 0    Error: HTTPSConnectionPool(host='www.forbes.co...          Forbes
# 1    Error: HTTPSConnectionPool(host='www.forbes.co...          Forbes
# 2    Error: HTTPSConnectionPool(host='thefly.com', ...      Thefly.com
# 3    Error: HTTPSConnectionPool(host='www.etfdailyn...  ETF Daily News
# 4    Error: HTTPSConnectionPool(host='www.globenews...   GlobeNewswire
# ..                                                 ...             ...
# 613  Error: HTTPSConnectionPool(host='slashdot.org'...    Slashdot.org
# 614  Error: HTTPSConnectionPool(host='slashdot.org'...    Slashdot.org
# 615  Access Denied (403) - Possible Paywall or Bot ...        Electrek
# 616  Access Denied (403) - Possible Paywall or Bot ...        Electrek
# 617  Error: HTTPSConnectionPool(host='www.thehindub...    BusinessLine
#
#                                                    URL
# 0    https://www.forbes.com/sites/johnnavin/2024/12...
# 1    https://www.forbes.com/sites/teresaghilarducci...
# 2    https://thefly.com/permalinks/entry.php/id4044...
# 3    https://www.etfdailynews.com/2025/01/01/bard-f...
# 4    https://www.globenewswire.com/news-release/202...
# ..                                                 ...
# 613  https://slashdot.org/firehose.pl?op=view&amp;i...
# 614  https://slashdot.org/firehose.pl?op=view&amp;i...
# 615  http://electrek.co/2025/01/29/elon-musk-tesla-...
# 616  http://electrek.co/2025/01/29/tesla-guides-ret...
# 617  https://www.thehindubusinessline.com/markets/s...
#
# [618 rows x 5 columns]

# %% [markdown]
# # Finnhub

# %%
import requests
import pandas as pd
from datetime import datetime, timedelta

# 1️⃣ Set up API key and parameters
FINNHUB_API_KEY = "cudi0gpr01qigebqu97gcudi0gpr01qigebqu980"  # Replace with your Finnhub API key
COMPANY_SYMBOL = "TSLA"  # Tesla's stock ticker symbol

# Define the date range (last 30 days)
end_date = datetime.today()
start_date = end_date - timedelta(days=30)

start_date_str = start_date.strftime("%Y-%m-%d")
end_date_str = end_date.strftime("%Y-%m-%d")

# 2️⃣ Fetch financial news from Finnhub
def fetch_finnhub_news(api_key, symbol, start_date, end_date):
    url = f"https://finnhub.io/api/v1/company-news"
    params = {
        "symbol": symbol,
        "from": start_date,
        "to": end_date,
        "token": api_key
    }

    response = requests.get(url, params=params)
    
    if response.status_code == 200:
        return response.json()  # Returns a list of news articles
    else:
        print(f"Error: {response.status_code} - {response.text}")
        return []

# 3️⃣ Process and save news data to Excel
def save_news_to_excel(news_data, output_file="finnhub_tesla_news.xlsx"):
    if not news_data:
        print("No news articles found.")
        return

    data = []
    for article in news_data:
        data.append({
            "Date": datetime.utcfromtimestamp(article["datetime"]).strftime("%Y-%m-%d"),
            "Headline": article["headline"],
            "Summary": article["summary"],
            "Source": article["source"],
            "URL": article["url"]
        })

    df = pd.DataFrame(data)
    
    # Save to an Excel file
    df.to_excel(output_file, index=False, engine="openpyxl")
    df.to_csv('finnhub_tesla_news.csv', index=False)
    print(f"✅ Data saved to {output_file}")
    return df

# 4️⃣ Run the script
if __name__ == "__main__":
    news_articles = fetch_finnhub_news(FINNHUB_API_KEY, COMPANY_SYMBOL, start_date_str, end_date_str)
    df=save_news_to_excel(news_articles)
# Out:
# ✅ Data saved to finnhub_tesla_news.xlsx

# %%
df
# Out:
#            Date                                           Headline  \
# 0    2025-01-30  Tesla: After Weak Q4 Earnings, I'm Reiterating...
# 1    2025-01-29    Giverny Capital Asset Management Q4 2024 Letter
# 2    2025-01-29                        Tesla: Q4 Earnings Snapshot
# 3    2025-01-29  Tesla, Inc. (TSLA) Q4 2024 Earnings Call Trans...
# 4    2025-01-29  Tesla commits to cheaper cars, says robotaxis ...
# ..          ...                                                ...
# 244  2025-01-09  Chinese Auto Sales Rose in December on Subsidi...
# 245  2025-01-09                                       BE GONE ELON
# 246  2025-01-08  The Best Car Stocks for 2025. Tesla Isn’t the ...
# 247  2025-01-08  NIO Stock May Have Reached a Turning Point, bu...
# 248  2025-01-08  Judge approves Tesla directors’ deal to end ex...
#
#                                                Summary        Source  \
# 0    Despite potential in robotaxis and AI, Tesla's...  SeekingAlpha
# 1    Giverny Capital Asset Management enjoyed marke...  SeekingAlpha
# 2    AUSTIN, Texas — AUSTIN, Texas — Tesla Inc. on ...       Finnhub
# 3    Tesla, Inc. (NASDAQ:TSLA) Q4 2024 Earnings Con...  SeekingAlpha
# 4    STORY: Tesla says it's working on delivering m...       Finnhub
# ..                                                 ...           ...
# 244  By Jiahui Huang China's vehicle sales rose sha...       Finnhub
# 245  Jess Phillips has said she has more important ...       Finnhub
# 246  Automotive investors are a gloomy bunch, and t...         Yahoo
# 247  NIO (NIO) stock has lost almost half of its va...         Yahoo
# 248  Tesla directors, including Chair Robyn Denholm...         Yahoo
#
#                                                    URL
# 0    https://finnhub.io/api/news?id=f6d6bba0128f6e3...
# 1    https://finnhub.io/api/news?id=d8a232d1e8cd700...
# 2    https://finnhub.io/api/news?id=e98c841563b0c1a...
# 3    https://finnhub.io/api/news?id=c435930f0452177...
# 4    https://finnhub.io/api/news?id=04c7556b8b6b238...
# ..                                                 ...
# 244  https://finnhub.io/api/news?id=86ae56683e87683...
# 245  https://finnhub.io/api/news?id=fe2b9e691d3ebae...
# 246  https://finnhub.io/api/news?id=331d2cb11f2b1a7...
# 247  https://finnhub.io/api/news?id=5ea38ac538ce4eb...
# 248  https://finnhub.io/api/news?id=bc4d5b6b23a215b...
#
# [249 rows x 5 columns]
